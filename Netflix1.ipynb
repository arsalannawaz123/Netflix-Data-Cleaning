# %%
import pandas as pd

# %%
df = pd.read_csv("netflix1.csv")
df_backup = df.copy()

df['show_id'] = df['show_id'].str.replace('s', '').astype(int)
df['date_added'] = pd.to_datetime(df['date_added'].str.strip())

# %%
new_col_names=[]
for i in df.columns:
    new_col_names.append(i.capitalize())
df.columns=new_col_names

# %%
df.columns
# Out:
# Index(['Show_id', 'Type', 'Title', 'Director', 'Country', 'Date_added',
#        'Release_year', 'Rating', 'Duration', 'Listed_in'],
#       dtype='str')

# %%
df.drop(columns='Rating')
# Out:
#       Show_id     Type                             Title         Director  \
# 0           1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1           3  TV Show                         Ganglands  Julien Leclercq
# 2           6  TV Show                     Midnight Mass    Mike Flanagan
# 3          14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4           8    Movie                           Sankofa     Haile Gerima
# ...       ...      ...                               ...              ...
# 8785     8797  TV Show                        Yunus Emre        Not Given
# 8786     8798  TV Show                         Zak Storm        Not Given
# 8787     8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788     8784  TV Show                              Yoko        Not Given
# 8789     8786  TV Show                               YOM        Not Given
#
#             Country Date_added  Release_year   Duration  \
# ...

# %%
df['Show_id']=df['Show_id'].replace('s','')

# %%
df.head()
# Out:
#    Show_id     Type                             Title         Director  \
# 0        1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        3  TV Show                         Ganglands  Julien Leclercq
# 2        6  TV Show                     Midnight Mass    Mike Flanagan
# 3       14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year Rating  Duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df['Duration_int']=df['Duration'].str.split(' ').str[0].astype(int)
df['Duration_unit']=df['Duration'].str.split(' ').str[1]

# %%
df.columns
# Out:
# Index(['Show_id', 'Type', 'Title', 'Director', 'Country', 'Date_added',
#        'Release_year', 'Rating', 'Duration', 'Listed_in', 'Duration_int',
#        'Duration_unit'],
#       dtype='str')

# %%
df.drop(columns='Duration')
# Out:
#       Show_id     Type                             Title         Director  \
# 0           1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1           3  TV Show                         Ganglands  Julien Leclercq
# 2           6  TV Show                     Midnight Mass    Mike Flanagan
# 3          14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4           8    Movie                           Sankofa     Haile Gerima
# ...       ...      ...                               ...              ...
# 8785     8797  TV Show                        Yunus Emre        Not Given
# 8786     8798  TV Show                         Zak Storm        Not Given
# 8787     8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788     8784  TV Show                              Yoko        Not Given
# 8789     8786  TV Show                               YOM        Not Given
#
#             Country Date_added  Release_year Rating  \
# ...

# %%
df.drop_duplicates()
# Out:
#       Show_id     Type                             Title         Director  \
# 0           1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1           3  TV Show                         Ganglands  Julien Leclercq
# 2           6  TV Show                     Midnight Mass    Mike Flanagan
# 3          14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4           8    Movie                           Sankofa     Haile Gerima
# ...       ...      ...                               ...              ...
# 8785     8797  TV Show                        Yunus Emre        Not Given
# 8786     8798  TV Show                         Zak Storm        Not Given
# 8787     8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788     8784  TV Show                              Yoko        Not Given
# 8789     8786  TV Show                               YOM        Not Given
#
#             Country Date_added  Release_year Rating   Duration  \
# ...

# %%
df.dropna()
# Out:
#       Show_id     Type                             Title         Director  \
# 0           1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1           3  TV Show                         Ganglands  Julien Leclercq
# 2           6  TV Show                     Midnight Mass    Mike Flanagan
# 3          14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4           8    Movie                           Sankofa     Haile Gerima
# ...       ...      ...                               ...              ...
# 8785     8797  TV Show                        Yunus Emre        Not Given
# 8786     8798  TV Show                         Zak Storm        Not Given
# 8787     8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788     8784  TV Show                              Yoko        Not Given
# 8789     8786  TV Show                               YOM        Not Given
#
#             Country Date_added  Release_year Rating   Duration  \
# ...

# %%
df['Show_id'].unique()
# Out:
# array([   1,    3,    6, ..., 8801, 8784, 8786], shape=(8790,))

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Show_id        8790 non-null   int64
#  1   Type           8790 non-null   str
#  2   Title          8790 non-null   str
#  3   Director       8790 non-null   str
#  4   Country        8790 non-null   str
#  5   Date_added     8790 non-null   datetime64[us]
#  6   Release_year   8790 non-null   int64
#  7   Rating         8790 non-null   str
#  8   Duration       8790 non-null   str
#  9   Listed_in      8790 non-null   str
#  10  Duration_int   8790 non-null   int64
#  11  Duration_unit  8790 non-null   object
# dtypes: datetime64[us](1), int64(3), object(1), str(7)
# memory usage: 824.2+ KB

# %%
df.head(5)
# Out:
#    Show_id     Type                             Title         Director  \
# 0        1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        3  TV Show                         Ganglands  Julien Leclercq
# 2        6  TV Show                     Midnight Mass    Mike Flanagan
# 3       14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year Rating  Duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            Listed_in  Duration_int  \
# 0                                      Documentaries            90
# ...

# %%
df.drop(columns='Duration',inplace=True)

# %%
df.head()
# Out:
#    Show_id     Type                             Title         Director  \
# 0        1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        3  TV Show                         Ganglands  Julien Leclercq
# 2        6  TV Show                     Midnight Mass    Mike Flanagan
# 3       14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year Rating  \
# 0  United States 2021-09-25          2020  PG-13
# 1         France 2021-09-24          2021  TV-MA
# 2  United States 2021-09-24          2021  TV-MA
# 3         Brazil 2021-09-22          2021  TV-PG
# 4  United States 2021-09-24          1993  TV-MA
#
#                                            Listed_in  Duration_int  \
# 0                                      Documentaries            90
# 1  Crime TV Shows, International TV Shows, TV Act...             1
# ...

# %%
df['Type'] = df['Type'].str.strip()
df['Title'] = df['Title'].str.strip()
df['Country'] = df['Country'].str.strip()

# %%
df.head()
# Out:
#    Show_id     Type                             Title         Director  \
# 0        1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        3  TV Show                         Ganglands  Julien Leclercq
# 2        6  TV Show                     Midnight Mass    Mike Flanagan
# 3       14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year Rating  \
# 0  United States 2021-09-25          2020  PG-13
# 1         France 2021-09-24          2021  TV-MA
# 2  United States 2021-09-24          2021  TV-MA
# 3         Brazil 2021-09-22          2021  TV-PG
# 4  United States 2021-09-24          1993  TV-MA
#
#                                            Listed_in  Duration_int  \
# 0                                      Documentaries            90
# 1  Crime TV Shows, International TV Shows, TV Act...             1
# ...

# %%
df['Duration_int'].mean()
# Out:
# np.float64(69.9344709897611)

# %%
df.columns
# Out:
# Index(['Show_id', 'Type', 'Title', 'Director', 'Country', 'Date_added',
#        'Release_year', 'Rating', 'Listed_in', 'Duration_int', 'Duration_unit'],
#       dtype='str')

# %%
df['Duration_unit'].value_counts()
# Out:
# Duration_unit
# min        6126
# Season     1791
# Seasons     873
# Name: count, dtype: int64

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.to_csv("Cleaned Netflix Data",index=False)
